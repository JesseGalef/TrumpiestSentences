# %%
# Jesse Galef
# Using data scraped from C-SPAN's uncorrected closed caption transcripts

# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
from bs4 import BeautifulSoup
import urllib

# %%
from scipy.sparse import csr_matrix, hstack
from scipy.stats import skew, kurtosis

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.grid_search import GridSearchCV 
from sklearn.cross_validation import StratifiedKFold

from sklearn.grid_search import GridSearchCV 

from sklearn.pipeline import Pipeline, make_pipeline, make_union, FeatureUnion
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.feature_selection import SelectPercentile, SelectKBest, chi2, f_classif

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
from spacy.en import English
from spacy import attrs
nlp_toolkit = English()
# This does word POS much much faster than nltk's pos_tagger

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
# NLTK's sent_tokenize looks more accurate than Spacy's, and I only need to run it once
from nltk.corpus import stopwords
stops = list(stopwords.words('english'))

# %%
from textblob import TextBlob
#

# %% [markdown]
# # POS dict

# %%
conjunctions = [u'and',u'that',u'but',u'or',u'as',u'if',u'when',u'than',u'because',
                u'while',u'where',u'after',u'so',u'though',u'since',u'until',u'whether',
                u'before',u'although',u'nor',u'like',u'once',u'unless',u'now',u'except']

# %%
pronouns = [u"all", u"another", u"any", u"anybody", u"anyone", u"anything", u"both", u"each", u"each other",
            u"either", u"everybody", u"everyone", u"everything", u"few", u"he", u"her", u"hers",
            u"herself", u"him", u"himself", u"his", u"i", u"it", u"its", u"itself", u"little",
            u"many", u"me", u"mine", u"more", u"most", u"much", u"my", u"myself", u"neither", 
            u"no one", u"nobody", u"none", u"nothing", u"one", u"one another", u"other", u"others",
            u"our", u"ours", u"ourselves", u"several", u"she", u"some", u"somebody", u"someone",
            u"something", u"that", u"their", u"theirs", u"them", u"themselves", u"these", u"they",
            u"this", u"those", u"us", u"we", u"what", u"whatever", u"which", u"whichever", u"who",
            u"whoever", u"whom", u"whomever", u"whose", u"you", u"your", u"yours", u"yourself", u"yourselves"]

# %% [markdown]
# # Transformer classes and Functions

# %%
def pipeline_features(step):
    # Passed a pipeline or pipeline step, recursively checks each named 
    # step and builds a list of features.
    # This returns the list in the same order that the estimator uses
    
    features = []
    if type(step)==Pipeline:
        for named_step in step.named_steps:
            features = features + pipeline_features(step.named_steps[named_step])
    elif type(step) == FeatureUnion:
        for transformer in step.transformer_list:
            features = features + pipeline_features(transformer[1])
    elif (type(step) == LogisticRegression):# or (type(step) == MultinomialNB):
        features = []
    else:
        features = step.get_feature_names()
    return features

# %%
def pipeline_coef_df(pipeline):
    # Passed a pipeline with estimator, creates a DataFrame of the coeficients for each class
    
    feature_list = pipeline_features(pipeline)
    if len(pipeline.named_steps['classifier'].classes_) == 2:
        coef_df = pd.DataFrame(pipeline.named_steps['classifier'].coef_, 
                           index = [pipeline.named_steps['classifier'].classes_[1]],
                           columns=feature_list).transpose()
        coef_df[pipeline.named_steps['classifier'].classes_[0]] = -coef_df[pipeline.named_steps['classifier'].classes_[1]]
    else:
        coef_df = pd.DataFrame(pipeline.named_steps['classifier'].coef_, 
                           index = pipeline.named_steps['classifier'].classes_, 
                           columns=feature_list).transpose()
    return np.e**(coef_df) # To get the odds ratios rather than the log odds
        
def top_coefs(pipeline, n_coefs):
    coef_df = pipeline_coef_df(pipeline)
    for candidate in coef_df.columns:
        print candidate,":"
        print coef_df.sort_values(by=candidate, ascending=False).ix[0:n_coefs,candidate]
        print

# %%
class word_length(TransformerMixin, BaseEstimator):
    
    def __init__(self):
#         self.min_length = min_length
#         self.max_length = max_length
#         self.bin_width = bin_width
        pass

    def fit(self, X, y=None, **fit_params):
        return self
    
    def transform(self, X, **transform_params):
        info = []
        for sentence in X:
            row = {}
            tokens =  [len(t) for t in re.findall('\\b\\w+\\b', sentence)]
            row['avg_word_length'] = sum(tokens)/float(len(tokens))
            row['word_length_skew'] = skew(tokens)
            row['word_length_kurtosis'] = kurtosis(tokens)
            info.append(row)
        return pd.DataFrame(info)
    
    def get_feature_names(self):
        return ['avg_word_length', 'word_length_skew','word_length_kurtosis']

# %%
class best_vectorizer(TransformerMixin, BaseEstimator):
    # Transformer that takes a vectorizer and sklearn selector (like SelectKBest or SelectPercentile)
    # to find the n best features
    
    def __init__(self, vectorizer, selector, name):
        self.vectorizer=vectorizer
        self.selector=selector
        self.name = name
    
    def fit(self, X, y, **fit_params):
        vectors = self.vectorizer.fit_transform(X)
        self.selector.fit(vectors, y)
#         self.vectorizer.vocbulary = self.get_feature_names()
        return self

    def transform(self, X, **transform_params):
        return self.selector.transform(self.vectorizer.transform(X))
    
    def get_feature_names(self):
        return [self.name+feature for feature, used in zip(self.vectorizer.get_feature_names(), self.selector.get_support()) if used==True]

# %%
class used_multiple(TransformerMixin, BaseEstimator):
    def __init__ (self, vectorizer):
        self.vectorizer = vectorizer

    def fit(self, X, y=None, **fit_params):
        self.vectorizer.fit(X)
        return self

    def transform(self, X, **transform_params):
        vectors = pd.DataFrame(self.vectorizer.transform(X).todense(), columns=self.vectorizer.get_feature_names())
        vectors = vectors[vectors>1]
        vectors.fillna(0, inplace=True)
        return vectors

    def get_feature_names(self):
        return ['multiple_'+feat for feat in self.vectorizer.get_feature_names()]

# %%
class repeats(TransformerMixin, BaseEstimator):
    def __init__ (self):
        self.vectorizer = CountVectorizer()
    
    def fit(self, X, y=None, **fit_params):
        self.vectorizer.fit(X)
        return self
    
    def transform(self, X):
        repeats = []
        for sentence in X:            
            sent_repeats = []
            tokenized = self.vectorizer.build_tokenizer()(sentence)
            for i in range(len(tokenized)-1):
                if tokenized[i]==tokenized[i+1]:
                    sent_repeats.append(tokenized[i])
            repeats.append(' '.join(sent_repeats))
        return pd.DataFrame(self.vectorizer.transform(repeats).todense(), columns=self.get_feature_names())
    
    def get_feature_names(self):
        return ['repeated_'+feat for feat in self.vectorizer.get_feature_names()]

# %%
class quick_stats(TransformerMixin, BaseEstimator):
    # Incredibly rough/crude stats on each sentence in order to be fast - no parsing
    
    def __init__(self):
        pass
    
    def fit(self, X, y=None, **fit_params):
        return self
    
    def transform(self, X, **transform_params):
        stats = []
        for sentence in X:
            stats.append({
                    'length': len(sentence),
                    'spaces': sentence.count(' '),
                    'avg_word_ish': len(sentence)/float(sentence.count(' ')+1),
                    'clause_breaks': sentence.count(',') + sentence.count('-'),
                })
        return pd.DataFrame(stats)
    
    def get_feature_names(self):
        return ['length', 'spaces', 'avg_word_ish', 'clause_breaks']

# %%
from scipy.sparse import diags

class sentiments(TransformerMixin, BaseEstimator):
    def __init__(self, vectorizer):
        self.vectorizer = vectorizer
    
    def fit(self, X, y=None):
        self.vectorizer.fit(X)
        return self
    
    def transform(self, X):
        sent_vectors = self.vectorizer.transform(X)
        polarities = []
        subjectivities = []
        for sentence in X:
            polarity, subjectivity = TextBlob(sentence).sentiment
            polarities.append(polarity)
            subjectivities.append(subjectivity)

        p_diag = diags(polarities,0)
        s_diag = diags(subjectivities,0)
#         print type(p_diag)
#         print type(s_diag)
#         print type(sent_vectors)
        polarity_vectors = p_diag.dot(sent_vectors)
        subjectivity_vectors = s_diag.dot(sent_vectors)
#         print polarity_vectors.shape
#         print subjectivity_vectors.shape
        return hstack([polarity_vectors,subjectivity_vectors])
    
    def get_feature_names(self):
        return ['polarity_'+i for i in self.vectorizer.get_feature_names()]+['subjectivity_'+i for i in self.vectorizer.get_feature_names()]

# %% [markdown]
# # Start reading data

# %%
republicans = ['Trump']#,'Cruz','Kasich','Rubio','Bush']
democrats = ['Clinton']#,'Sanders']

long_df = pd.DataFrame()
for candidate in republicans+democrats:
    long_df = long_df.append(pd.read_csv(candidate+"_transcript_df.csv",index_col=0),ignore_index=True)

# %%
long_df.shape
# Out:
# (186, 6)

# %%
long_df.speaker.value_counts()
# Out:
# Trump      97
# Clinton    89
# Name: speaker, dtype: int64

# %%
# %%time
sentence_list = []
for idx, speech in long_df.iterrows():
    raw = unicode(speech.text,errors='ignore').lower().replace('  ',' ').replace('>','').replace('w3','').replace(' v ','')
    #Fixing a few known glitches in the C-SPAN transcribing service
    sentences = sent_tokenize(raw)
    for sentence in sentences:
        sent_info = {}
        sent_info['sentence'] = sentence
        sent_info['speaker'] = speech.speaker
        sent_info['date'] = speech.date
        sent_info['title'] = speech.title
        sent_info['speech_idx'] = idx
        sent_info['tokens'] = len(re.findall('\\b\\w+\\b', sentence))
        sentence_list.append(sent_info)
raw_df = pd.DataFrame(sentence_list)
# Out:
# CPU times: user 8.35 s, sys: 247 ms, total: 8.6 s
# Wall time: 8.48 s

# %%
raw_df.speaker.value_counts()
# Out:
# Trump      41131
# Clinton    17649
# Name: speaker, dtype: int64

# %%
raw_df[raw_df.tokens <=200].tokens.hist(bins=50)
plt.xlim([0,100])
# Out:
# (0, 100)

# %%
declarations = {}
declarations['Trump'] = '2015-06-16'
declarations['Clinton'] = '2015-04-11'

# %%
for i in range(20):
    print i, len(raw_df[raw_df.tokens>=i])/float(len(raw_df))
# Out:
# 0 1.0
# 1 0.999574685267
# 2 0.982647158898
# 3 0.949880911875
# 4 0.897669275264
# 5 0.821725076557
# 6 0.737002381763
# 7 0.655512078938
# 8 0.580163320857
# 9 0.515226267438
# 10 0.45945899966
# 11 0.409544062606
# 12 0.366400136101
# 13 0.328291936033
# 14 0.295661789724
# 15 0.265209254849
# 16 0.237682885335
# 17 0.21318475672
# 18 0.191187478734
# 19 0.171554950663

# %%
min_length = 10
max_length = 150
df = raw_df[raw_df.tokens >= min_length]
df = df[df.tokens <= max_length]
# post_dec = [date > dec for date,dec in zip(df.date, [declarations[candidate] for candidate in df.speaker])]
# df = df[post_dec]

# %%
df.speaker.value_counts()
# Out:
# Trump      15699
# Clinton    11305
# Name: speaker, dtype: int64

# %%
max(df.speaker.value_counts())/float(len(df))
# Out:
# 0.58135831728632792

# %% [markdown]
# # Data In, configure Pipeline

# %%
from sklearn.feature_selection import SelectFromModel
vectorizer = CountVectorizer(
#                          max_features = 7000,
                         ngram_range=(1,2), 
#                          stop_words='english',
                         decode_error='ignore',
                         min_df = 5,
                         binary=True,
                        token_pattern = '(?u)\\b\\w+\\b',
                            )

all_features = [
#     ('top_words', vectorizer),
      ('top_words', best_vectorizer(vectorizer, selector=SelectFromModel(estimator=LogisticRegression(penalty='l1')), name='')),
#     ('word_length', word_length()),
#      ('sentiments', sentiments(vectorizer)),
#     ('quickstats', quick_stats()),
#     ('consec', best_vectorizer(repeats(), selector=SelectKBest(chi2, 20), name='')),
#     ('multiple', used_multiple(CountVectorizer())),
    ]

# %%
pipeline = Pipeline([
  ('features', FeatureUnion(all_features)), # Currently the best_vectorizer
    ('classifier', LogisticRegression())]
)

# %% [markdown]
# # Cross Validate

# %%
which_candidates = ['Clinton','Trump']

# %%
from sklearn.cross_validation import cross_val_score
import time

# %%
#  class sklearn.linear_model.LogisticRegression(penalty='l2', dual=False, 
# tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, 
# random_state=None, solver='liblinear', max_iter=100, multi_class='ovr', verbose=0, 
# warm_start=False, n_jobs=1)[source]

# %%
t0=time.time()

condition = [speaker in which_candidates for speaker in df.speaker]
cand_df = df[condition]
kf = StratifiedKFold(y=cand_df.speaker, n_folds=3,random_state=42)
params = {'classifier__C': [.3,1,3],
#           'classifier__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag'],
#           'features__sentiments__vectorizer__min_df': [1000,2000,4000,'all'],
          'features__top_words__vectorizer__min_df': [1,5,10],
          'features__top_words__vectorizer__max_df': [.5,.25,.15],
          'features__top_words__selector__estimator__penalty': ['l2','l1'],
          'features__top_words__selector__estimator__C': [.3,1,3],
         }

grid = GridSearchCV(estimator=pipeline, param_grid = params, scoring = 'roc_auc',cv=kf, verbose=2)

grid.fit(cand_df.sentence,[1 if speaker == 'Trump' else 0 for speaker in cand_df.speaker])
print time.time()-t0
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.6s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:  3.2min
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   7.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   7.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   7.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   9.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   7.7s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   8.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -21.5min
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=1, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   8.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   6.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   4.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function chi2 at 0x115149e60> -   5.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   6.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   5.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70>
# [Parallel(n_jobs=1)]: Done 161 tasks       | elapsed: 35.6min
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=3, features__top_words__selector__score_func=<function f_classif at 0x115149d70> -   4.8s
# [Parallel(n_jobs=1)]: Done 162 out of 162 | elapsed: 35.7min finished
# 2149.58984208

# %%
scores = grid.grid_scores_
grid.best_params_
# Out:
# {'classifier__C': 1,
#  'features__top_words__selector__score_func': <function sklearn.feature_selection.univariate_selection.f_classif>,
#  'features__top_words__vectorizer__max_df': 0.5,
#  'features__top_words__vectorizer__min_df': 1}

# %%
cv = []
scores = grid.grid_scores_
for combo in scores:
    pars = combo[0]
    pars['mean'] = combo[1]
    cv.append(pars)
pd.DataFrame(cv).sort_values(by='mean',ascending=False)
# Out:
#     classifier__C features__top_words__selector__score_func  \
# 27            1.0       <function f_classif at 0x115149d70>
# 18            1.0            <function chi2 at 0x115149e60>
# 30            1.0       <function f_classif at 0x115149d70>
# 21            1.0            <function chi2 at 0x115149e60>
# 33            1.0       <function f_classif at 0x115149d70>
# 24            1.0            <function chi2 at 0x115149e60>
# 9             0.3       <function f_classif at 0x115149d70>
# 0             0.3            <function chi2 at 0x115149e60>
# 12            0.3       <function f_classif at 0x115149d70>
# 3             0.3            <function chi2 at 0x115149e60>
# 15            0.3       <function f_classif at 0x115149d70>
# 6             0.3            <function chi2 at 0x115149e60>
# 45            3.0       <function f_classif at 0x115149d70>
# 36            3.0            <function chi2 at 0x115149e60>
# 39            3.0            <function chi2 at 0x115149e60>
# 48            3.0       <function f_classif at 0x115149d70>
# 51            3.0       <function f_classif at 0x115149d70>
# 42            3.0            <function chi2 at 0x115149e60>
# 19            1.0            <function chi2 at 0x115149e60>
# 28            1.0       <function f_classif at 0x115149d70>
# 31            1.0       <function f_classif at 0x115149d70>
# 37            3.0            <function chi2 at 0x115149e60>
# 22            1.0            <function chi2 at 0x115149e60>
# 25            1.0            <function chi2 at 0x115149e60>
# 34            1.0       <function f_classif at 0x115149d70>
# 46            3.0       <function f_classif at 0x115149d70>
# 1             0.3            <function chi2 at 0x115149e60>
# 10            0.3       <function f_classif at 0x115149d70>
# 49            3.0       <function f_classif at 0x115149d70>
# 40            3.0            <function chi2 at 0x115149e60>
# 43            3.0            <function chi2 at 0x115149e60>
# 52            3.0       <function f_classif at 0x115149d70>
# 13            0.3       <function f_classif at 0x115149d70>
# 4             0.3            <function chi2 at 0x115149e60>
# 16            0.3       <function f_classif at 0x115149d70>
# 7             0.3            <function chi2 at 0x115149e60>
# 29            1.0       <function f_classif at 0x115149d70>
# 20            1.0            <function chi2 at 0x115149e60>
# 47            3.0       <function f_classif at 0x115149d70>
# 38            3.0            <function chi2 at 0x115149e60>
# 11            0.3       <function f_classif at 0x115149d70>
# 2             0.3            <function chi2 at 0x115149e60>
# 32            1.0       <function f_classif at 0x115149d70>
# 23            1.0            <function chi2 at 0x115149e60>
# 50            3.0       <function f_classif at 0x115149d70>
# 41            3.0            <function chi2 at 0x115149e60>
# 26            1.0            <function chi2 at 0x115149e60>
# 35            1.0       <function f_classif at 0x115149d70>
# 14            0.3       <function f_classif at 0x115149d70>
# 5             0.3            <function chi2 at 0x115149e60>
# 44            3.0            <function chi2 at 0x115149e60>
# 53            3.0       <function f_classif at 0x115149d70>
# 8             0.3            <function chi2 at 0x115149e60>
# 17            0.3       <function f_classif at 0x115149d70>
#
#     features__top_words__vectorizer__max_df  \
# 27                                     0.50
# 18                                     0.50
# 30                                     0.25
# 21                                     0.25
# 33                                     0.15
# 24                                     0.15
# 9                                      0.50
# 0                                      0.50
# 12                                     0.25
# 3                                      0.25
# 15                                     0.15
# 6                                      0.15
# 45                                     0.50
# 36                                     0.50
# 39                                     0.25
# 48                                     0.25
# 51                                     0.15
# 42                                     0.15
# 19                                     0.50
# 28                                     0.50
# 31                                     0.25
# 37                                     0.50
# 22                                     0.25
# 25                                     0.15
# 34                                     0.15
# 46                                     0.50
# 1                                      0.50
# 10                                     0.50
# 49                                     0.25
# 40                                     0.25
# 43                                     0.15
# 52                                     0.15
# 13                                     0.25
# 4                                      0.25
# 16                                     0.15
# 7                                      0.15
# 29                                     0.50
# 20                                     0.50
# 47                                     0.50
# 38                                     0.50
# 11                                     0.50
# 2                                      0.50
# 32                                     0.25
# 23                                     0.25
# 50                                     0.25
# 41                                     0.25
# 26                                     0.15
# 35                                     0.15
# 14                                     0.25
# 5                                      0.25
# 44                                     0.15
# 53                                     0.15
# 8                                      0.15
# 17                                     0.15
#
#     features__top_words__vectorizer__min_df      mean
# 27                                        1  0.903936
# 18                                        1  0.903894
# 30                                        1  0.903067
# 21                                        1  0.903059
# 33                                        1  0.902842
# 24                                        1  0.902829
# 9                                         1  0.902515
# 0                                         1  0.902496
# 12                                        1  0.901622
# 3                                         1  0.901609
# 15                                        1  0.901333
# 6                                         1  0.901326
# 45                                        1  0.900247
# 36                                        1  0.900193
# 39                                        1  0.899405
# 48                                        1  0.899405
# 51                                        1  0.899237
# 42                                        1  0.899220
# 19                                        5  0.880215
# 28                                        5  0.880121
# 31                                        5  0.878940
# 37                                        5  0.878825
# 22                                        5  0.878822
# 25                                        5  0.878755
# 34                                        5  0.878719
# 46                                        5  0.878694
# 1                                         5  0.878653
# 10                                        5  0.878624
# 49                                        5  0.877598
# 40                                        5  0.877483
# 43                                        5  0.877451
# 52                                        5  0.877431
# 13                                        5  0.877348
# 4                                         5  0.877183
# 16                                        5  0.876991
# 7                                         5  0.876987
# 29                                       10  0.864450
# 20                                       10  0.864418
# 47                                       10  0.863836
# 38                                       10  0.863804
# 11                                       10  0.863208
# 2                                        10  0.863160
# 32                                       10  0.861543
# 23                                       10  0.861499
# 50                                       10  0.860984
# 41                                       10  0.860916
# 26                                       10  0.860600
# 35                                       10  0.860551
# 14                                       10  0.860274
# 5                                        10  0.860242
# 44                                       10  0.860062
# 53                                       10  0.860040
# 8                                        10  0.859296
# 17                                       10  0.859265

# %% [markdown]
# ## Build a cross-val-predict-proba

# %%
pipeline=grid.best_estimator_

# %%
import time

cand_df = df[[speaker in which_candidates for speaker in df.speaker]]

n_folds = 20

segment_results = pd.DataFrame()
all_results = pd.DataFrame()
segment_coefs = [pd.DataFrame()]*n_folds

kf = StratifiedKFold(y=cand_df.speaker, n_folds =n_folds,random_state=42)

for i, (train_index, test_index) in enumerate(kf):
    t0 = time.time()
    pipeline.fit(cand_df.iloc[train_index].sentence, cand_df.iloc[train_index].speaker)
#     print 'done fitting',i,"time:",time.time()-t0
    segment_coefs[i] = pipeline_coef_df(pipeline)
    segment_results = pd.DataFrame(
                                    pipeline.predict_proba(cand_df.iloc[test_index].sentence),
                                    index=list(cand_df.iloc[test_index].index),
                                    columns=pipeline.named_steps['classifier'].classes_)
    print 'done predicting',i,"time:",time.time()-t0

    all_results=all_results.append(segment_results)
# Out:
# done predicting 0 time: 7.43759489059
# done predicting 1 time: 7.37171792984
# done predicting 2 time: 6.45584893227
# done predicting 3 time: 8.72200393677
# done predicting 4 time: 8.09515500069
# done predicting 5 time: 7.30533099174
# done predicting 6 time: 7.41375303268
# done predicting 7 time: 7.45828700066
# done predicting 8 time: 6.88970708847
# done predicting 9 time: 7.06043481827
# done predicting 10 time: 6.86395597458
# done predicting 11 time: 7.54950690269
# done predicting 12 time: 7.61496901512
# done predicting 13 time: 9.24345016479
# done predicting 14 time: 9.46743702888
# done predicting 15 time: 7.92821311951
# done predicting 16 time: 7.90242695808
# done predicting 17 time: 7.55941009521
# done predicting 18 time: 7.46357584
# done predicting 19 time: 7.24793386459

# %%
cv_result = cand_df.copy().join(all_results)

# %%
cv_result.groupby('speaker').mean()
# Out:
#          speech_idx     tokens   Clinton     Trump
# speaker
# Clinton  141.634498  20.579655  0.759391  0.240609
# Trump     48.424231  17.535257  0.172723  0.827277

# %%
cv_result['predict'] = cv_result.apply(lambda x: x[which_candidates].argmax(), axis = 1)

# %%
cv_result['correct'] = cv_result.predict == cv_result.speaker

# %%
cv_result.correct.value_counts()
# Out:
# True     22892
# False     4112
# Name: correct, dtype: int64

# %%
cv_result.correct.value_counts()[1]/float(len(cv_result.correct))
# Out:
# 0.84772626277588503

# %%
#  sklearn.metrics.roc_curve(y_true, y_score, pos_label=None, sample_weight=None, drop_intermediate
correct= [1 if speaker == 'Trump' else 0 for speaker in cv_result.speaker]
roc = roc_curve(correct, y_score=list(cv_result.Trump))
print roc_auc_score(correct, cv_result.Trump)
plt.plot(roc[0], roc[1])
# Out:
# 0.923235630358

# %%
sns.set_palette('deep')

# %%
plt.plot(cv_result[(cv_result.tokens <=60)&(cv_result.tokens >=2)].groupby('tokens').mean()['correct'])

# %%
cv_result.head()
# Out:
#           date                                           sentence speaker  \
# 10  2016-09-03  i just wrote this the other day knowing that i...   Trump
# 11  2016-09-03  for centuries, the african american church has...   Trump
# 12  2016-09-03  it is from the pews and pulpits and christian ...   Trump
# 13  2016-09-03    and we are bound together and i see that today.   Trump
# 15  2016-09-03  the african-american fate immunity has been on...   Trump
#
#     speech_idx                                              title  tokens  \
# 10           1  Presidential Candidate Donald Trump Remarks in...      42
# 11           1  Presidential Candidate Donald Trump Remarks in...      15
# 12           1  Presidential Candidate Donald Trump Remarks in...      58
# 13           1  Presidential Candidate Donald Trump Remarks in...      10
# 15           1  Presidential Candidate Donald Trump Remarks in...      19
#
#      Clinton     Trump  predict correct
# 10  0.017816  0.982184    Trump    True
# 11  0.184348  0.815652    Trump    True
# 12  0.928026  0.071974  Clinton   False
# 13  0.269423  0.730577    Trump    True
# 15  0.395368  0.604632    Trump    True

# %%
for candidate in which_candidates:
    print "Most",candidate,":"
    for idx, row in cv_result[cv_result.speaker == cv_result.predict].sort_values(by=candidate,ascending=False).iloc[0:10].iterrows():
        sent = row.sentence
        print "\t",sent[0].upper()+sent[1:]
        print "--",row.speech_idx, row.title
        print long_df.loc[row.speech_idx].link
        print "Predicted Clinton: ",row.Clinton
        print "Predicted Trump: ",row.Trump
        print
    print
    print
# Out:
# Most Clinton :
# 	I hope you will join me and that you will be part of this effort to build on the progress we have made under president obama to go further and to make it absolutely clear that we are fighting to break down barriers wherever they may be because we know america deserves nothing less and americans deserve to have the future that we will create together.
# -- 138 Presidential Candidate Hillary Clinton Rally in Orangeburg, South Carolina
# http://www.c-span.org/video/?405395-1/hillary-clinton-campaign-rally-orangeburg-south-carolina
# Predicted Clinton:  0.999999999891
# Predicted Trump:  1.08642969026e-10
#
# 	I do not think president obama gets the credit he deserves for saving our economy from what could have been an even worse crisis, saving the auto industry, cracking down on wall street abuses which the bush administration had been ignoring, and passing the affordable care act which now provides health insurance to 18 million americans!
# -- 164 Presidential Candidate Hillary Clinton Campaign Rally in Las Vegas
# http://www.c-span.org/video/?328637-1/hillary-clinton-campaign-rally-las-vegas
# Predicted Clinton:  0.999999999672
# Predicted Trump:  3.2817634449e-10
#
# 	When we fight to make college more affordable than stupid deathless punishing work to hold corporations accountable when they tell just one try to prices or falluja or environment or exploit workers, that's fighting for women and men in america and when we fight to create a pathway to citizenship for millions of immigrants, we will make social security even stronger or to protect and improve the affordable care act because everyone deserves access to quality affordable care.
# -- 162 Hillary Clinton at Democratic Women's Leadership Forum
# http://www.c-span.org/video/?328919-3/hillary-clinton-democratic-womens-leadership-forum
# Predicted Clinton:  0.999999999641
# Predicted Trump:  3.59418922065e-10
#
# 	Think of what we are losing because we are not doing everything we can to reach out to those families and we know again from so much research year in the united states and around the world that mentoring and intervention will help those often stressed out young moms understand more about what they can do and to avoid the difficulties that stand in the way of their being able to get their child off to the best possible start.
# -- 181 Presidential Candidate Hillary Clinton Economic Policy Address
# http://www.c-span.org/video/?327052-1/hillary-clinton-economic-policy-address
# Predicted Clinton:  0.999999999497
# Predicted Trump:  5.02684380404e-10
#
# 	You see, i have a broader view about what we need to do to make sure that people not only pay their fair share, but they don't wreck the economy like we saw them in 2008. the governor, senator, and i agree that we have got to prevent wall street, the financial markets, and others from doing what they did.
# -- 150 Hillary Clinton Campaign Rally in Cedar Rapids, Iowa
# http://www.c-span.org/video/?403935-1/hillary-clinton-campaign-rally-cedar-rapids-iowa
# Predicted Clinton:  0.999999999303
# Predicted Trump:  6.97082659482e-10
#
# 	I also have to say that i have heard a lot about another challenge that gets too little attention in our long-term looking forward into the future about what kind of country we are going to be and how we can help people live up to their potential.
# -- 167 2015 New Hampshire Democratic Party State Convention
# http://www.c-span.org/video/?328108-1/2015-new-hampshire-democratic-party-state-convention
# Predicted Clinton:  0.999999999005
# Predicted Trump:  9.94880858053e-10
#
# 	Our highest priority, of course, must always be protecting the american people, so, yes, we do need to be vigilant in screening refugees from syria guided by the best judgment of our security professionals in close coordination with our allies and partners and congress needs to make sure the necessary resources are provided for comprehensive background checks drawing on the best intelligence we can get, and we should be taking a close look at the safe guards and the visa programs as well, but we cannot allow terrorist to intimidate us in abandoning our values and our humanitarian obligations.
# -- 159 Presidential Candidate Hillary Clinton National Security Address
# http://www.c-span.org/video/?400960-1/hillary-clinton-national-security-address
# Predicted Clinton:  0.999999996133
# Predicted Trump:  3.86686073867e-09
#
# 	You all have to decide, who is ready to be president and commander in chief on day one of january 2017. and if you will go caucus for me on monday night, if you will go stand up for me, if you will be there for me, i promise you this -- i will stand for you, i will fight for you through this campaign, and in the white house i will work my heart out for you for the kind of future of our country that we all deserve and want.
# -- 150 Hillary Clinton Campaign Rally in Cedar Rapids, Iowa
# http://www.c-span.org/video/?403935-1/hillary-clinton-campaign-rally-cedar-rapids-iowa
# Predicted Clinton:  0.99999999533
# Predicted Trump:  4.67002495555e-09
#
# 	No family and no student should have to borrow to pay tuition at a public college or university and everyone who has student debt should be able to refinance it at lower rates, costs not a barrier, and that will not hold you back under my plan.
# -- 176 Presidential Candidate Hillary Clinton Press Availability
# http://www.c-span.org/video/?327572-2/presidential-candidate-hillary-clinton-press-availability
# Predicted Clinton:  0.999999994446
# Predicted Trump:  5.55398338988e-09
#
# 	When i think about you're hired, that is what i want us all to be focused on -- creating more jobs, raising income for people, beginning to reduce inequality in income by making sure our economy works for everybody, not just those at the top.
# -- 106 Presidential Candidate Hillary Clinton Rally in Annandale, Virginia
# http://www.c-span.org/video/?412723-1/senator-tim-kaine-campaigns-hillary-clinton
# Predicted Clinton:  0.99999999133
# Predicted Trump:  8.6700457686e-09
#
#
#
# Most Trump :
# 	As you know, we have done very  well with the evangelicals and  with religion generally speaking, if you look at what's  happened with all of the races, whether it's in south carolina,  i went there and it was supposed to be strong evangelical, and i  was not supposed to win and i won in a landslide, and so many other places where you had the evangelicals and you had the  heavy christian groups and it was just -- it's been an amazing journey to have -- i think we won 37 different states.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  2.1366730607e-10
# Predicted Trump:  0.999999999786
#
# 	And i want to tell you, you know, so much about illegal immigration and so much has been mentioned about it and talked about it and these politicians are all talk, no action, they are never going to do anything, and they are only going to pick this up because when i went and i announced that i was running for president, i said, you know, his country is a big, big problem with illegal immigration, and all of a sudden, we started talking about it, and then we had bad things happening, and there was crime and you had so many killings and so much crime.
# -- 45 Presidential Candidate Donald Trump Rally in Arizona
# http://www.c-span.org/video/?406905-1/donald-trump-campaign-rally-phoenix-arizona
# Predicted Clinton:  1.9065278245e-09
# Predicted Trump:  0.999999998093
#
# 	Believe me, we are going to use our great business people to negotiate unbelievable trade deals so we bring our jobs back and we don't let our companies go to mexico and all of these other countries anymore.
# -- 36 Presidential Candidate Donald Trump New York Primary Night Speech
# http://www.c-span.org/video/?408385-1/donald-trump-primary-night-speech
# Predicted Clinton:  1.56767621107e-08
# Predicted Trump:  0.999999984323
#
# 	I would go to a company like carrier air-conditioning which decided to leave indianapolis and i would say, here's the story coming you think it's wonderful that you are negotiating with mexico come i'm sure you will have a wonderful plant -- if you bill that plant and you fire all these people who were so great to me -- indiana come i won that in a landslide -- the timing was good.
# -- 7 Donald Trump Campaign Rally in Erie, Pennsylvania
# http://www.c-span.org/video/?413909-1/donald-trump-campaigns-erie-pennsylvania
# Predicted Clinton:  2.30718532057e-08
# Predicted Trump:  0.999999976928
#
# 	And just to finish on the nuclear thing, i was talking about negotiating with japan and negotiate with germany and i have such negotiators in the world, carl icahn, other negotiators, a lot of people want to come in and help us, some of the greatest business minds, and they all want to help us, so i say to myself, "look at this, look at these people, and look at this negotiation.
# -- 41 Donald Trump Town Hall Meeting in Rothschild, Wisconsin
# http://www.c-span.org/video/?407558-1/donald-trump-town-hall-meeting-rothschild-wisconsin
# Predicted Clinton:  2.71689150066e-08
# Predicted Trump:  0.999999972831
#
# 	Yet hillary clinton for months and despite so many attacks repeatedly refused to even say the words radical islam until i challenged her yesterday and guess what, she will probably say them, she sort of has said them but let's see what happens, she really has no choice but she doesn't want, however, she's really been forced and she has been forced to say these words, she supports and the reason is she supports so much of what is wrong and what is wrong with this country and what's going wrong with our country and our borders.
# -- 23 Donald Trump Remarks in Manchester, New Hampshire
# http://www.c-span.org/video/?410976-1/donald-trump-delivers-remarks-national-security-threats
# Predicted Clinton:  1.3553811018e-07
# Predicted Trump:  0.999999864462
#
# 	They are great people and i said i'm going to win and a lot of hispanics here illegally don't want people coming in illegally.
# -- 88 Presidential Candidate Donald Trump Speech in Nashville, Tennessee
# http://www.c-span.org/video/?327853-1/donald-trump-remarks-nashville-tennessee
# Predicted Clinton:  3.29036512814e-07
# Predicted Trump:  0.999999670963
#
# 	When you see a guy like jeb is, a less than average guy having all of this money where they give him $128 billion waste and then he takes out ads against me, i think he spent $25 million on negative ads against me and my poll numbers went up.
# -- 63 Presidential Candidate Donald Trump Town Hall Meeting in Londonderry, New Hampshire
# http://www.c-span.org/video/?404296-1/donald-trump-town-hall-meeting-londonderry-new-hampshire
# Predicted Clinton:  3.52149132632e-07
# Predicted Trump:  0.999999647851
#
# 	So what we are going to do is we are going to tell our wonderful businesses that deserted us, they left us, and i'm not even blaming them, they had no reason not to, because nobody talks -- you think somebody went to carry her and said, you listen coming you let all of these people go, don't go to mexico?
# -- 45 Presidential Candidate Donald Trump Rally in Arizona
# http://www.c-span.org/video/?406905-1/donald-trump-campaign-rally-phoenix-arizona
# Predicted Clinton:  4.26020267841e-07
# Predicted Trump:  0.99999957398
#
# 	When a company wants to leave our country to go to another country and think they are going to make their product and because our politicians are weak, stupid, taken care of by lobbyists, special interests, they are taken care of by lobbyists, they are taken care of by donors and special interests -- a friend of mine said i can't believe we're talking about a deal that took place a month ago.
# -- 7 Donald Trump Campaign Rally in Erie, Pennsylvania
# http://www.c-span.org/video/?413909-1/donald-trump-campaigns-erie-pennsylvania
# Predicted Clinton:  4.27789484947e-07
# Predicted Trump:  0.999999572211

# %%
cv_result.to_csv('cv_result_sept_19.csv')
cv_result.to_csv('cv_result.csv')

# %%
for candidate in which_candidates:
    print "Most",candidate+"-like, but not:"
    for idx, row in cv_result[cv_result.speaker != cv_result.predict].sort_values(by=candidate,ascending=False).iloc[0:10].iterrows():
        sent = row.sentence
        print "\t",sent[0].upper()+sent[1:]
        print "--",row.speech_idx, row.title
        print long_df.loc[row.speech_idx].link
        print "Predicted Clinton: ",row.Clinton
        print "Predicted Trump: ",row.Trump
        print
    print
    print
# Out:
# Most Clinton-like, but not:
# 	This is why we have already  passed legislation to support  wounded warriors, veterans who  struggle with mental health challenges and earlier this week to support female veterans in  particular who need our help.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.999968474521
# Predicted Trump:  3.15254793165e-05
#
# 	That's why we passed --  -- that's why we also pass add  bill that helps victims of child pornography get restitution from those who frost from their pain  and took steps to crack down on so-called pass the trash practice of schools.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.999946927996
# Predicted Trump:  5.30720042093e-05
#
# 	If we get serious and put our differences aside we can create an environment where we can fix these things, save social kurt y security, arrest the rising  nature of our health care costs and put this country in a direction for our children and grandchildren to where we  swroent to look at them and  apologize.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.999385992176
# Predicted Trump:  0.000614007823915
#
# 	Every action i take, i will ask myself: does this make life better for young americans in baltimore, chicago, detroit, and ferguson who have really come in every way, have the same right to live out their dreams as any other child in america?
# -- 11 Donald Trump 2016 Acceptance Speech
# http://www.c-span.org/video/?412402-8/donald-trump-2016-acceptance-speech
# Predicted Clinton:  0.999346788591
# Predicted Trump:  0.000653211409268
#
# 	Two years ago actually passed the first balanced budget plan passed by congress since 2001. laid out a path, david perdue, he, i and several others working on plan to reform the budget process.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.999306987526
# Predicted Trump:  0.000693012474277
#
# 	New york values were on display for all to see in the aftermath of 9/11 that struck at the heart of our city and our nation.
# -- 38 Donald Trump Remarks at New York State Republican Gala
# http://www.c-span.org/video/?408067-1/2016-new-york-state-republican-gala
# Predicted Clinton:  0.999190074269
# Predicted Trump:  0.000809925731346
#
# 	That's why just last month we were not -- we not only reauthorized the adam wallchack  but provided additional rights  and protections for victims of  sexual assault.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.998972267676
# Predicted Trump:  0.00102773232426
#
# 	For example, one victory we did have late last year, we passed the bill in the house and the senate to repeal obamacare completely.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.998875179447
# Predicted Trump:  0.00112482055312
#
# 	We eventually passed critical,  compassionate and comprehensive  legislation to help victims of modern slavery and, of course,  the president had to choice at  that point but to sign it.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.998867588858
# Predicted Trump:  0.00113241114189
#
# 	David is spotting for georgians  and all of us every day in the u.s. senate, and is committed to solving our national debt and global security crisis.
# -- 22 Faith and Freedom Coalition Conference
# http://www.c-span.org/video/?410912-1/faith-freedom-coalition-holds-annual-conference
# Predicted Clinton:  0.998834346943
# Predicted Trump:  0.00116565305653
#
#
#
# Most Trump-like, but not:
# 	What i do not approve of is what happened in san francisco, because if you are going to have quote sanctuary cities where law enforcement will tell the immigrant community you won't get in trouble if you report the murder, rape, burglary, and you are an otherwise a law-abiding citizen, that is one thing.
# -- 169 WMUR-TV Interview with Presidential Candidate Hillary Clinton
# http://www.c-span.org/video/?327904-1/wmurtv-interview-presidential-candidate-hillary-clinton
# Predicted Clinton:  0.00128238150689
# Predicted Trump:  0.998717618493
#
# 	On that very same day that those people were killed in oregon, a five-month-old baby strapped into her car seat in the back of a car was killed by a stray bullet in cleveland.
# -- 165 Presidential Candidate Hillary Clinton Remarks on Gun Violence
# http://www.c-span.org/video/?328577-1/hillary-clinton-remarks-gun-violence
# Predicted Clinton:  0.00173233584025
# Predicted Trump:  0.99826766416
#
# 	This is an honor because she and i used to run a little potluck together and we would have people over and we would have a little potluck.
# -- 172 Presidential Candidate Hillary Clinton Meet-and-Greet at the Iowa State Fair, Part 1
# http://www.c-span.org/video/?327525-8/presidential-candidate-hillary-clinton-meetandgreet-iowa-state-fair-part-1
# Predicted Clinton:  0.00179694505123
# Predicted Trump:  0.998203054949
#
# 	But what marco rubio said has as much of an impact in terms of where the republican party is today as anybody else on that stage.
# -- 176 Presidential Candidate Hillary Clinton Press Availability
# http://www.c-span.org/video/?327572-2/presidential-candidate-hillary-clinton-press-availability
# Predicted Clinton:  0.00385257422699
# Predicted Trump:  0.996147425773
#
# 	And he has reached out and he has invited people, and they just get further and further away, and their attitude basically has become -- they don't even like the run speaker of the house.
# -- 164 Presidential Candidate Hillary Clinton Campaign Rally in Las Vegas
# http://www.c-span.org/video/?328637-1/hillary-clinton-campaign-rally-las-vegas
# Predicted Clinton:  0.00525576505679
# Predicted Trump:  0.994744234943
#
# 	And then i was supposed to go speak to the parliament.
# -- 155 Presidential Candidate Hillary Clinton in Portsmouth, New Hampshire
# http://www.c-span.org/video/?402565-1/hillary-clinton-town-hall-meeting-portsmouth-new-hampshire
# Predicted Clinton:  0.00610952354047
# Predicted Trump:  0.99389047646
#
# 	I said, if she was coming to the united states, if i could meet with her.
# -- 163 Presidential Candidate Hillary Clinton in Keene, New Hampshire
# http://www.c-span.org/video/?328774-1/hillary-clinton-town-hall-meeting-keene-new-hampshire
# Predicted Clinton:  0.00650234541958
# Predicted Trump:  0.99349765458
#
# 	Hedge fund guys have started a super pac to run against me.
# -- 150 Hillary Clinton Campaign Rally in Cedar Rapids, Iowa
# http://www.c-span.org/video/?403935-1/hillary-clinton-campaign-rally-cedar-rapids-iowa
# Predicted Clinton:  0.00780729338713
# Predicted Trump:  0.992192706613
#
# 	One that embeds our mission within isis within radical jehadism that's bigger than any one group.
# -- 159 Presidential Candidate Hillary Clinton National Security Address
# http://www.c-span.org/video/?400960-1/hillary-clinton-national-security-address
# Predicted Clinton:  0.00855669786773
# Predicted Trump:  0.991443302132
#
# 	I'm a little worried that are a sometimes the federal you and government has the you message of don't do anything will message of don't do anything until we get there.
# -- 165 Presidential Candidate Hillary Clinton Remarks on Gun Violence
# http://www.c-span.org/video/?328577-1/hillary-clinton-remarks-gun-violence
# Predicted Clinton:  0.00878592803186
# Predicted Trump:  0.991214071968

# %%
sums = {}
for candidate in which_candidates:
    sums[candidate] = pd.DataFrame(index=segment_coefs[0].index)
t0 = time.time()
for i, segment in enumerate(segment_coefs):
    segment.drop_duplicates(inplace=True)
    for candidate in which_candidates:
        sums[candidate] = sums[candidate].join(segment[candidate], rsuffix=str(i))
        sums[candidate].drop_duplicates(inplace=True)

# %%
average_coef = pd.DataFrame()

for candidate in which_candidates:
    sums[candidate].fillna(1.0, inplace=True) # odds ratio
    #     average_coef[candidate] = sums[candidate].apply(lambda x: len(x) / sum([1./i for i in x]), axis=1)
    logged = np.log(sums[candidate])
    average_coef[candidate] = np.e**(logged.sum(axis=1) /  logged.shape[1])

# %%
print average_coef.sort_values(by='Trump', ascending=False).head(50)['Trump']
print
print average_coef.sort_values(by='Clinton', ascending=False).head(50)['Clinton']
# Out:
# tremendous            11.743402
# guy                   10.083858
# york values            9.839317
# is all                 9.226653
# islamic                8.799853
# media                  8.090533
# frankly                7.725966
# allowed                7.424902
# nice                   7.325783
# guys                   7.316077
# illegal                7.206939
# japan                  7.150513
# almost                 6.954816
# transgender            6.940144
# ivanka                 6.655448
# incredible             6.582949
# does it                6.318744
# terms                  6.253879
# establishment          6.182713
# largest                6.089849
# david                  6.087929
# hell                   6.069673
# television             6.068346
# poll                   5.900390
# five                   5.861722
# hillary                5.811402
# sex                    5.659927
# hispanics              5.659732
# politician             5.502492
# my wife                5.463731
# conservative           5.458862
# christian              5.456676
# golf                   5.427222
# we passed              5.416765
# history of             5.366750
# illegal immigrants     5.315771
# politicians            5.203695
# fox                    5.144669
# an example             5.124926
# 50                     5.083263
# leaving                5.048864
# deals                  5.043931
# bernie                 5.009406
# numbers                4.976122
# into our               4.934729
# us from                4.929677
# massive                4.907944
# country back           4.871990
# common core            4.782131
# stupid                 4.747621
# Name: Trump, dtype: float64
#
# my husband         12.915590
# wall street        11.039275
# attention          10.715966
# citizens united     9.957895
# investment          9.815577
# arkansas            8.951927
# opportunities       7.897532
# or us               7.643680
# auto                7.519704
# recession           7.204347
# learning            7.128844
# deserves            6.842934
# wage                6.758650
# advanced            6.746906
# grateful            6.511700
# republicans         6.385679
# about what          6.315172
# proposal            6.125600
# goodness            6.083278
# drug                6.067572
# i remember          6.064165
# progress            6.022533
# invest              5.995736
# affordable          5.961497
# democratic          5.871162
# progressive         5.814121
# ideas               5.806978
# com                 5.713780
# can to              5.693373
# kids                5.686850
# particularly        5.628121
# a raise             5.594003
# mother              5.521756
# solar               5.373700
# climate             5.327420
# college             5.240736
# clean energy        5.175590
# it did              5.131593
# why i               5.027047
# experiences         5.019577
# i quote             5.006309
# run a               5.005763
# nice things         5.003819
# often               4.950087
# the tax             4.939779
# past                4.873558
# corporations        4.854398
# majority of         4.853104
# forward             4.852199
# this campaign       4.841096
# Name: Clinton, dtype: float64

# %%
average_coef.to_csv('average_coef_sept_19.csv')
average_coef.to_csv('average_coef.csv')

# %%
def color_map(percent, top, bottom):
    if percent >1:
        percent = 1
    diff = [t-b for t,b in zip(top, bottom)]
    
    return [(d*percent)+b for d,b in zip(diff, bottom)]

# %%
pronoun_coefs = average_coef.loc[[col for col in average_coef.index if col in pronouns]].sort_values('Trump', ascending=False)
# toplot = pronoun_coefs[((pronoun_coefs.Trump >= 1) | (pronoun_coefs.Clinton >=1))].copy()
toplot = pronoun_coefs.iloc[0:10].append(pronoun_coefs.iloc[-10:])

# %%
f, (ax1) = plt.subplots(1,1, figsize=(12,9))
label_size = 12
value_size = 9

vals = [np.log(x) for x in toplot.sort_values('Trump', ascending=False).Trump]

#minimum=abs(min(vals))
maximum=max(vals)
minimum=maximum
blue=[0,.1,.8]
red = [.8,.1,0]
white = [1,1,1]
colors = [color_map(-value/minimum, blue, white) if value < 0 else color_map(value/maximum, red, white) for value in vals]


sns.barplot(x=vals,
            y=toplot.sort_values('Trump', ascending=False).index, ax=ax1,
            palette=colors, 
#             color=colors,
            edgecolor='black')

ax1.set_title("How Pronouns Multiply the Predicted Odds that\nClinton or Trump Was the Speaker\n", fontsize=28, color=[.25,.25,.25])

# ax1.set_yticklabels([x[0].upper()+x[1:] for x in toplot.sort_values('Trump', ascending=False).index.values], fontsize=16)


labels = [x[0].upper()+x[1:] for x in toplot.sort_values('Trump', ascending=False).index.values]
for i, patch in enumerate(ax1.patches):
    width = patch.get_width()
    
    if patch.get_x() < 0:
        # Bars extending on the left
        label_x = .05
        label_halign = 'left'
        if patch.get_width() >= np.log(1.15):     
            value_x = patch.get_x()+.04
            value_halign = 'left'
        else:
            value_x = patch.get_x()-.04
            value_halign='right'
    else:
        # Bars extending on the right
        label_x = -.05
        label_halign = 'right'
        if patch.get_width() >= np.log(1.15):
            value_x = patch.get_width()-.04
            value_halign = 'right'
        else:
            value_x = patch.get_width() + .04
            value_halign = 'left'

    value_color = [.1,.1,.1]
    if patch.get_width()> np.log(2): value_color = 'white'
    ax1.text(label_x, patch.get_y()+.61, '%s'%(labels[i]), color=[.1,.1,.1], ha=label_halign, fontsize=label_size)   
    ax1.text(value_x, patch.get_y()+.61, '%1.2f'%(np.e**abs(vals[i])), color=value_color, ha=value_halign, fontsize=label_size)    

            
ax1.text(-np.log(2.95), 14, 'Clinton', color='b', fontsize=24)
ax1.text(np.log(2.95), 5, 'Trump', color='r', fontsize=24, ha='right')

ax1.set_yticklabels([])
ax1.set_xlabel('')
ax1.set_xlim([-np.log(5),np.log(5)])

ax1.set_xticks([-np.log(4),-np.log(3),-np.log(2),0,np.log(2),np.log(3), np.log(4)], minor=False)
ax1.set_xticklabels([4,3,2,1,2,3,4], minor=False)

f.text(.95, .07, 'by\nJesse Galef', color=[.2,.2,.2], fontsize=12, alpha=.8, ha='right', weight='bold', variant='small-caps')


plt.plot()
f.tight_layout(rect=[0,0,.95,.95])

# %%
print toplot.sort_values('Trump')['Clinton'][:15]
print toplot.sort_values('Clinton')['Trump'][:15]
# Out:
# each          3.253735
# each other    2.240911
# themselves    2.220751
# both          2.191085
# either        2.115804
# others        1.843142
# several       1.792265
# everyone      1.788419
# more          1.753420
# who           1.749716
# nothing       0.612857
# everybody     0.531386
# they          0.512087
# somebody      0.478821
# she           0.469143
# Name: Clinton, dtype: float64
# nobody       3.504754
# myself       2.855898
# these        2.177312
# its          2.176424
# him          2.158825
# she          2.131548
# somebody     2.088463
# they         1.952792
# everybody    1.881870
# nothing      1.631701
# who          0.571521
# more         0.570314
# everyone     0.559153
# several      0.557953
# others       0.542552
# Name: Trump, dtype: float64

# %%
#  seaborn.barplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, 
#  estimator=<function mean>, ci=95, n_boot=1000, units=None, orient=None, color=None,
#  palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, ax=None, **kwargs)¶
f, ax1 = plt.subplots(1,1, figsize=(15,9))

ax1.set_yticks([-1*np.log(x) for x in range(10,1,-1)]+[0]+[np.log(y) for y in range(2,11)])
    
ax1.set_yticklabels(range(10,1,-1)+['1']+range(2,11))


ax1.set_ylabel('')

label_font_size = 14
value_font_size=11
rotate =60
n_words = 20

color_adjustment = np.log(3)
val_series = average_coef.sort_values('Trump', ascending=False)['Trump']
vals = val_series[:n_words].append(val_series[-n_words:])
vals = np.log(vals)

# minimum=abs(min(vals))
maximum=max(vals)
minimum=maximum
blue=[0,.1,.8]
red = [.8,.1,0]
white = [1,1,1]

colors = [color_map(-(value+color_adjustment)/(minimum-color_adjustment), blue, white) if value < 0 else color_map((value-color_adjustment)/(maximum-color_adjustment), red, white) for value in vals]

sns.barplot(y=vals,
            x=vals.index, ax=ax1,
            palette=colors, 
#             color=colors,
            edgecolor='black')

ax1.set_xticks([])
ax1.set_xlabel('')
ax1.set_title("Top "+str(n_words)+" Words/Phrases that Multiply the Predicted Odds\nClinton or Trump was the Speaker\n", fontsize=28, color=[.25,.25,.25])


labels = [x[0].upper()+x[1:] for x in vals.sort_values(ascending=False).index.values]

for i, patch in enumerate(ax1.patches):
    height = patch.get_height()
    if patch.get_y() < 0:
#         y = patch.get_y() -.5
        if height > np.log(6): 
            color = 'white'
        else:
            color = 'black'

        ax1.text(patch.get_x()+.1, .1, '%s'%(labels[i]), color=[.1,.1,.1], va='bottom', ha='left', rotation=rotate, fontsize=label_font_size)
        ax1.text(patch.get_x()+.15, patch.get_y()+.15, '%1.2f'%(np.e**abs(vals[i])), color=color, rotation=90, va='bottom', fontsize=value_font_size)
    else:
        if height > np.log(7): 
            color = 'white'
        else:
            color = 'black'
        ax1.text(patch.get_x()+.7, -.05, '%s'%(labels[i]), color=[.1,.1,.1], ha='right', va='top', rotation=rotate, fontsize=label_font_size)
        ax1.text(patch.get_x()+.15, patch.get_y()+height-.3, '%1.2f'%(np.e**abs(vals[i])), color=color, rotation = 90, va='bottom', fontsize=value_font_size)

            
f.text(.95, .95, 'Jesse Galef', color=[.2,.2,.2], fontsize=16, alpha=.8, ha='right', weight='bold', variant='small-caps')

ax1.set_ylim([-np.log(14), np.log(14)])

# ax1.yaxis.tick_right()
# ax1.yaxis.set_ticks_position('both')

for i, ygrid in enumerate(ax1.get_ygridlines()):
#     print ygrid.get_ydata(orig=False)[0], np.log(2)
#     if abs(ygrid.get_ydata(orig=True)[0]) == np.log(2):
    if i==8 or i==10:
        ygrid.set_xdata([0,0])

plt.grid(which='major', color=[.7,.7,.7], alpha=.7)
plt.margins(.3)
plt.plot()
f.tight_layout(rect=[0,0,.95,.95])

# %%
print average_coef.loc['believe']
print average_coef.loc['believe me']
# Out:
# Clinton    0.784319
# Trump      1.274992
# Name: believe, dtype: float64
# Clinton    0.312158
# Trump      3.203502
# Name: believe me, dtype: float64

# %%
joint_c = '\n'.join(df[df.speaker == 'Clinton'].sentence)
joint_t = '\n'.join(df[df.speaker == 'Trump'].sentence)

# %%
word = 'frankly'
print joint_c.count(word)
print joint_t.count(word)
# Out:
# 7
# 57

# %% [markdown]
# # Not caring about coefficients

# %%
from sklearn.ensemble import RandomForestClassifier


vectorizer2 = CountVectorizer(
#                          max_features = 7000,
                         ngram_range=(1,3), 
#                          stop_words='english',
                         decode_error='ignore',
                         min_df = 5,
                         binary=True,
                        token_pattern = '(?u)\\b\\w+\\b',
                            )

all_features2 = [
#     ('top_words', vectorizer),
#     ('sentiment_terms', sentiments(vectorizer)),
      ('top_words', best_vectorizer(vectorizer, selector=SelectPercentile(chi2, percentile=10), name='')),
#     ('word_length', word_length()),
#       ('sent_pipe',Pipeline([
#             ('selector',best_vectorizer(vectorizer, selector=SelectKBest(chi2, 3000), name='')),
#             ('sentiment_terms', sentiments(vectorizer)),]))
#     ('quickstats', quick_stats()),
#     ('consec', best_vectorizer(repeats(), selector=SelectKBest(chi2, 20), name='')),
#     ('multiple', used_multiple(CountVectorizer())),
    ]
    
    
pipeline2 = Pipeline([
  ('features', FeatureUnion(all_features2)),
    ('classifier', LogisticRegression())]
)

# %%
t0=time.time()

condition = [speaker in which_candidates for speaker in df.speaker]
cand_df = df[condition]
kf = StratifiedKFold(y=cand_df.speaker, n_folds=4,random_state=42)
params = {'classifier__C': [.3,1,3,6],
#           'classifier__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag'],
#           'features__sentiments__vectorizer__min_df': [1000,2000,4000,'all'],
          'features__top_words__vectorizer__min_df': [1,5,10],
          'features__top_words__vectorizer__max_df': [.5,.25,.15],
          'features__top_words__selector__percentile': [1,5,25,100]
         }

grid = GridSearchCV(estimator=pipeline2, param_grid = params, scoring = 'roc_auc',cv=kf, verbose=2)

grid.fit(cand_df.sentence,[1 if speaker == 'Trump' else 0 for speaker in cand_df.speaker])
print time.time()-t0
# Out:
# Fitting 4 folds for each of 144 candidates, totalling 576 fits
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   9.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.7s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   7.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -   8.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=1 -  10.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:  5.6min
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  13.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  11.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  11.6s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.7s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.6s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -   9.6s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=5 -  10.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   8.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   8.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   8.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   8.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -  11.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.6s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   8.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -  10.0s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=25 -   9.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  12.3s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  12.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  12.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  14.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  12.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.1s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=0.3, features__top_words__selector__percentile=100 -   8.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.9s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.9s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  11.7s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.8s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.7s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=0.3, features__top_words__selector__percentile=100 -  10.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__percentile=1 -  10.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__percentile=1
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__percentile=1 -  10.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=1, features__top_words__selector__percentile=1
# ...
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=25 -   8.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   8.4s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   8.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -  10.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -   9.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=25 -  10.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  15.0s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  14.2s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  13.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  12.5s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  10.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -  10.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.1s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.5, classifier__C=6, features__top_words__selector__percentile=100 -   9.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  11.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  12.1s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  13.4s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  14.6s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  12.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -   9.9s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.4s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.5s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.25, classifier__C=6, features__top_words__selector__percentile=100 -  10.6s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  12.8s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  11.5s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  12.7s
# [CV] features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=1, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  12.0s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  10.2s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  11.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  10.3s
# [CV] features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=5, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  10.3s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -   9.2s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -   9.7s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  10.8s
# [CV] features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100
# [CV]  features__top_words__vectorizer__min_df=10, features__top_words__vectorizer__max_df=0.15, classifier__C=6, features__top_words__selector__percentile=100 -  11.0s
# [Parallel(n_jobs=1)]: Done 576 out of 576 | elapsed: 96.4min finished
# 5802.34498692

# %%
grid.best_params_
# Out:
# {'classifier__C': 6,
#  'features__top_words__selector__percentile': 100,
#  'features__top_words__vectorizer__max_df': 0.5,
#  'features__top_words__vectorizer__min_df': 1}

# %%
estimator = pipeline2.best_estimator_

cand_df = df[[speaker in which_candidates for speaker in df.speaker]]

n_folds = 20

segment_results = pd.DataFrame()
all_results = pd.DataFrame()

kf = StratifiedKFold(y=cand_df.speaker, n_folds =n_folds,random_state=42)

for i, (train_index, test_index) in enumerate(kf):
    t0 = time.time()
    estimator.fit(cand_df.iloc[train_index].sentence, cand_df.iloc[train_index].speaker)
#     print 'done fitting',i,"time:",time.time()-t0
    segment_results = pd.DataFrame(
                                    estimator.predict_proba(cand_df.iloc[test_index].sentence),
                                    index=list(cand_df.iloc[test_index].index),
                                    columns=estimator.named_steps['classifier'].classes_)
    print 'done predicting',i,"time:",time.time()-t0

    all_results=all_results.append(segment_results)

# %%
np.log(average_coef.Trump).hist(bins=70)
plt.xlim([-1,1])
# Out:
# (-1, 1)

# %%
[(term, average_coef.loc[term].Trump) for term in average_coef.index if 'myself' in term]
# Out:
# [(u'about myself', 1.0084831029090571),
#  (u'after myself', 1.1609274543461532),
#  (u'against myself', 1.0110664929577986),
#  (u'and myself', 1.0091312940460684),
#  (u'and myself and', 1.0018703771645592),
#  (u'ask myself', 1.2588388615071335),
#  (u'ask myself i', 1.0813209957440582),
#  (u'bay myself', 1.030838672030125),
#  (u'call on myself', 1.015874886720842),
#  (u'calling myself', 1.0280713802990806),
#  (u'came to myself', 1.007419347663284),
#  (u'do it myself', 1.2677417795620272),
#  (u'for myself', 1.2721999580244558),
#  (u'for myself except', 1.0014927828100286),
#  (u'including myself', 0.93922806349606858),
#  (u'it myself', 1.2846175245101135),
#  (u'it myself but', 1.0534321245556484),
#  (u'it myself folks', 1.0022320549549255),
#  (u'listen to myself', 0.74310146647165332),
#  (u'myself', 2.7183047499564452),
#  (u'myself a', 1.0115805912886076),
#  (u'myself and', 0.96312554963135577),
#  (u'myself and i', 1.1718263066155088),
#  (u'myself back', 1.0501993037669364),
#  (u'myself because', 1.2214163585399824),
#  (u'myself because i', 1.0450963667644619),
#  (u'myself but', 1.1671727937519081),
#  (u'myself but it', 1.0410094433205053),
#  (u'myself i', 1.2435567228940447),
#  (u'myself is', 1.0175761488635491),
#  (u'myself is anybody', 1.0018346358276695),
#  (u'myself now', 1.0292558673006973),
#  (u'myself waterboarding', 1.0009528146912445),
#  (u'myself we', 1.00850768775765),
#  (u'myself what', 1.0348285902975203),
#  (u'myself you', 1.0024971401684477),
#  (u'of myself', 1.1326810789545974),
#  (u'of myself and', 1.0973077459045635),
#  (u'on myself', 1.0367465837436496),
#  (u'pay myself', 1.1875347190053176),
#  (u'pay myself back', 1.0173935595288373),
#  (u'said to myself', 1.1303401986692494),
#  (u'say to myself', 1.0463618235117107),
#  (u'saying to myself', 1.1177821986969714),
#  (u'to myself', 1.0949138199041626),
#  (u'to myself and', 1.0300251907959515),
#  (u'to myself i', 1.0518478642772537),
#  (u'to myself is', 1.0078371910185453)]
